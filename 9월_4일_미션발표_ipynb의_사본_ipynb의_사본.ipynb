# %% [markdown]
# <a href="https://colab.research.google.com/github/NayoungShin/projectmanager/blob/main/9%EC%9B%94_4%EC%9D%BC_%EB%AF%B8%EC%85%98%EB%B0%9C%ED%91%9C_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 새 섹션

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df1=pd.read_csv('./sample_data/사설학원+및+독서실(2009년+이후)_20230903161807.csv')

df1.rename(columns={'자치구별(2)':'자치구','2022.1':'학원수'}, inplace=True)
df1.iloc[5:,[1,3]]   #자치구별 총 학원수만 추출

df1 = df1.iloc[5:,[1,3]]   #자치구별 총 학원수만 추출
df1['학원수'] = df1['학원수'].astype({ '학원수' : 'int' })
df1.sort_values(by = '학원수', ascending = False)  #내림차순으로 정렬이 이루어짐


##data type을 숫자형태로 바꿔주고 data를 추출
# Out:
#      자치구   학원수
# 27   강남구  2007
# 28   송파구  1010
# 19   양천구  1004
# 26   서초구   915
# 15   노원구   674
# 20   강서구   661
# 29   강동구   660
# 18   마포구   511
# 16   은평구   490
# 12   성북구   443
# 9    광진구   378
# 21   구로구   352
# 24   동작구   348
# 23  영등포구   341
# 10  동대문구   329
# 25   관악구   328
# 17  서대문구   296
# 14   도봉구   281
# 8    성동구   249
# 11   중랑구   244
# 13   강북구   193
# 22   금천구   185
# 7    용산구   129
# 5    종로구   106
# 6     중구    63

# %%
#데이터의 시각화( 구별 학원수)

# plt.rc('font', family='Malgun Gothic')          # (win)한글 폰트
plt.rc('font', family='NanumBarunGothic')       # (코랩)한글 폰트


# 1.그래프 데이터 지정하기(X축, Y축)
x =df1['자치구']       # 자치구
y =df1['학원수']   # 학원수


# 2.그래프 그리기
plt.bar(x, y)

# 3. 그래프 꾸미기
plt.title('서울시 구별 학원수와 집값 지수와의 관계') # 그래프 제목
plt.xlabel('자치구')                    # x축 이름
plt.ylabel('학원수')                  # y축 이름
plt.xticks(rotation = 70)             # X축 레이블 회전
# plt.yticks(np.arrange(60,2000,100))
plt.show()                            # 그래프 출력하기

# %%
df2=pd.read_csv('./sample_data/주택가격지수(매매)_20230903160304.csv')
df2.rename(columns={'시점':'년도', '자치구별(1)':'서울시','자치구별(2)':'자치구별', '종합':'모든주택가격', '아파트':'아파트가격'}, inplace=True) # 컬럼명 변경
df2
# df2.query("년도.str.contains('2022')")
# # df2.query(" 년도 == '2022' ")
# # df2_2022
#df2[ df2['년도']=='2022' ]   #2022 년도 data추출 실패;;;;;
# Out:
#        년도  서울시 자치구별  모든주택가격  아파트가격
# 0    1986  서울시   소계    34.0   20.1
# 1    1986  서울시  강북구    47.6   28.9
# 2    1986  서울시  강남구    25.6   17.1
# 3    1987  서울시   소계    34.7   21.1
# 4    1987  서울시  강북구    48.2   28.8
# ..    ...  ...  ...     ...    ...
# 566  2022  서울시  관악구    98.7   96.6
# 567  2022  서울시  서초구   103.1  102.8
# 568  2022  서울시  강남구   101.2  100.9
# 569  2022  서울시  송파구    98.8   96.1
# 570  2022  서울시  강동구    99.0   96.5
#
# [571 rows x 5 columns]

# %%
df3=pd.read_csv('./sample_data/주택가격지수(매매)_2022.csv')
# df3.sort_values(by='종합', ascending=False)

df3.rename(columns={'시점':'년도', '자치구별(1)':'서울시','자치구별(2)':'자치구', '종합':'모든주택가격', '아파트':'아파트가격'},inplace=True)
df3.sort_values(by='모든주택가격', ascending=False)
# Out:
#       년도  서울시   자치구  모든주택가격  아파트가격
# 21  2022  서울시   서초구   103.1  102.8
# 2   2022  서울시   용산구   101.4  100.3
# 22  2022  서울시   강남구   101.2  100.9
# 0   2022  서울시   종로구   100.2   96.0
# 19  2022  서울시   동작구   100.2   98.9
# 4   2022  서울시   광진구   100.0   97.1
# 14  2022  서울시   양천구    99.1   97.0
# 16  2022  서울시   구로구    99.0   97.9
# 24  2022  서울시   강동구    99.0   96.5
# 3   2022  서울시   성동구    99.0   97.6
# 13  2022  서울시   마포구    98.8   96.4
# 8   2022  서울시   강북구    98.8   91.8
# 6   2022  서울시   중랑구    98.8   95.7
# 23  2022  서울시   송파구    98.8   96.1
# 20  2022  서울시   관악구    98.7   96.6
# 15  2022  서울시   강서구    98.6   97.6
# 17  2022  서울시   금천구    98.5   95.6
# 11  2022  서울시   은평구    98.3   93.8
# 18  2022  서울시  영등포구    98.1   96.6
# 5   2022  서울시  동대문구    97.7   94.3
# 12  2022  서울시  서대문구    97.4   93.9
# 1   2022  서울시    중구    96.9   93.8
# 7   2022  서울시   성북구    96.5   92.9
# 9   2022  서울시   도봉구    96.0   91.4
# 10  2022  서울시   노원구    93.8   92.2

# %%
# 1.그래프 데이터 지정하기(X축, Y축)
x = df3['자치구']       # 자치구
y = df3['모든주택가격']   # 모든주택가격


# 2.그래프 그리기
plt.plot(x, y)

# 3. 그래프 꾸미기
plt.title('서울시 구별 학원수와 집값 지수와의 관계') # 그래프 제목
plt.xlabel('자치구')                    # x축 이름
plt.ylabel('모든주택가격')                  # y축 이름
plt.xticks(rotation = 70)             # X축 레이블 회전
# plt.yticks(np.arrange(60,2000,100))
plt.show()                            # 그래프 출력하기

# %%
# 1. (코랩) 한글 폰트 설치하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (16.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...
